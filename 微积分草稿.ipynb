# %%
import sympy as sp

# %%
x,y=sp.symbols('x,y')
sp.Integral(x**2*y,(y,0,sp.sqrt(1-x**2)),(x,0,1)).doit()
# Out:
# 1/15

# %%
sp.simplify(sp.Integral(sp.E**(x+y),(y,0,1),(x,0,1)).doit())
# Out:
# -2*E + 1 + exp(2)
