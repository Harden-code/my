# %%
from sympy import *
x,y=symbols('x,y',positive=True)

# %%
logcombine(ln(x)+log(y))
# Out:
# log(x*y)

# %%
Integral(1/(x*ln(x)),x).doit()
# Out:
# log(log(x))

# %%
expr=(3*x**2+14*x)/(x**3+7*x**2+7)
Integral(expr,x).doit()
# Out:
# log(x**3 + 7*x**2 + 7)

# %%
expr=x*(3*x+2)**Rational(1,5)

expr
# Out:
# x*(3*x + 2)**(1/5)

# %%
expr=(3*x**2+2)**Rational(6,5)

expr.diff()
# Out:
# 36*x*(3*x**2 + 2)**(1/5)/5

# %%
expr=x*(3*x+2)**Rational(1,5)
factor(Integral(expr,x).doit())
# Out:
# 5*(3*x + 2)**(6/5)*(9*x - 5)/297
