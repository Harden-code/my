# %%
import numpy as np
import sympy as sp
import matplotlib.pyplot as plt

x,y,n,i=sp.symbols('x,y,n,i')

# %% [markdown]
# ### 集合论符号
# 属于符号
#
# ```math
# b \in B(b属于B)
# ````
#
# ```math
# a \notin B (a不属于B)
# ````
#
# ```math
# B \ni b
# ````
# ```math
# B \notni a
# ````
# ```math
# ````

# %%
sp.sqrt(x)
# Out:
# sqrt(x)
